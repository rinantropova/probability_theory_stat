# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1
# Постройте графики для приведенных наборов данных. Найдите коэффициенты для линии
# регрессии и коэффициенты детерминации. Что вы замечаете? Нанесите на график модель
# линейной регрессии
# .
# X1= np.array([30,30,40, 40
# )]
# Y1= np.array([37, 47, 50, 6
# 0)]
# x2= np.array([30,30,40, 40, 20, 20, 50,
# 50])
# y2= np.array([37, 47, 50, 60, 25, 35, 62,
#  72])
# X3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60
# , 60])
# Y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])

# %%
x1= np.array([30, 30, 40, 40])
y1= np.array([37, 47, 50, 60])

# %%
x2= np.array([30,30,40, 40, 20, 20, 50, 50])
y2= np.array([37, 47, 50, 60, 25, 35, 62, 72])

# %%
x3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60 , 60])
y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])

# %%
models = [[x1, y1], [x2, y2], [x3, y3]]

# %%
fig, axis = plt.subplots(3, 1)
for i in range(len(models)):
    cor = np.corrcoef(models[i])[0][1]
    axis[i].scatter(models[i][0], models[i][1])
    axis[i].set_title(f'r = {round(cor, 3)}')

plt.tight_layout()

# %%
# reshape
print('before', models[1][0])
for i in range(len(models)):
    models[i][0] = models[i][0].reshape(-1, 1)

print('after', models[1][0])
# Out:
# before [30 30 40 40 20 20 50 50]
# after [[30]
#  [30]
#  [40]
#  [40]
#  [20]
#  [20]
#  [50]
#  [50]]

# %%
# regression
from sklearn.linear_model import LinearRegression

# %%
for i in range(len(models)):
    model = LinearRegression()
    model.fit(models[i][0], models[i][1])
    r_sq = model.score(models[i][0], models[i][1])
    print(f'model {i + 1}')
    print(f'R2: {round(r_sq, 3)}')
    print(f'const: {round(model.intercept_, 3)}')
    print(f'beta: {model.coef_}')
    print('-' * 30)
# Out:
# model 1
# R2: 0.628
# const: 3.0
# beta: [1.3]
# ------------------------------
# model 2
# R2: 0.885
# const: 5.1
# beta: [1.24]
# ------------------------------
# model 3
# R2: 0.946
# const: 5.6
# beta: [1.22571429]
# ------------------------------

# %%
# plot
fig, axis = plt.subplots(3, 1)
for i in range(len(models)):
    x = models[i][0]
    y = models[i][1]
    model = LinearRegression()
    model.fit(x, y)
    r_sq = model.score(x, y)
    const = model.intercept_
    beta = model.coef_[0]

    axis[i].scatter(x, y)
    axis[i].set_title(f'R2 = {round(r_sq, 3)}')

    axis[i].plot(x, beta * x + const, 'g')

plt.tight_layout()

# %% [markdown]
# ## Task 2

# %%
x = np.array([10,8, 13, 9,11,14, 6,4,12, 7,5])
y = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68 ])

# %%
model = LinearRegression()
x = x.reshape(-1, 1)
model.fit(x, y)
r_sq = model.score(x, y)

const = model.intercept_
beta = model.coef_[0]
const, beta
# Out:
# (3.0000909090909103, 0.5000909090909091)

# %%
plt.scatter(x, y)
plt.plot(x, beta * x + const, 'g')
plt.title(f'R2 = {round(r_sq, 3)}')
plt.xlabel('x')
plt.ylabel('y')
plt.show();

# %% [markdown]
# ## Task 3
# проверка остатков

# %%
from scipy import stats

# %%
y_hat = beta * x + const
y_hat = y_hat.reshape(1, -1)
resid = y - y_hat
print(resid)

plt.figure(figsize=(3, 3))
plt.scatter(x, resid)
plt.xlabel('x')
plt.ylabel('residuals')
plt.show();

stats.shapiro(resid) # Тест на нормальное распределение Н0: распределение нормальное
# Out:
# [[ 0.039      -0.05081818 -1.92127273  1.30909091 -0.17109091 -0.04136364
#    1.23936364 -0.74045455  1.83881818 -1.68072727  0.17945455]]
# ShapiroResult(statistic=0.9421076645229962, pvalue=0.5455846842938501)

# %%
# гомоскедастичность
plt.figure(figsize=(3, 3))
plt.scatter(y_hat, resid)
plt.xlabel('y_hat')
plt.ylabel('residuals')
plt.show();

# %% [markdown]
# ## Task 4
# значимость модели

# %%
n = x.shape[0]
m = 1

k1 = m
k2 = n - m - 1

k1, k2
# Out:
# (1, 9)

# %%
alpha = 0.05

t = stats.f.ppf(1 - alpha, k1, k2)
t
# Out:
# 5.117355029199227

# %%
R2 = r_sq
F = (R2 / k1) / ((1 - R2) / k2)
F
# Out:
# 17.98994296767698

# %%
# F > t => принимаем Н1, модель значимая. H0: R2 = 0 - отвергается.

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(x)
model = sm.OLS(y, x)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.667
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                     17.99
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):            0.00217
# Time:                        13:27:50   Log-Likelihood:                -16.841
# No. Observations:                  11   AIC:                             37.68
# Df Residuals:                       9   BIC:                             38.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0001      1.125      2.667      0.026       0.456       5.544
# x1             0.5001      0.118      4.241      0.002       0.233       0.767
# ==============================================================================
# Omnibus:                        0.082   Durbin-Watson:                   3.212
# Prob(Omnibus):                  0.960   Jarque-Bera (JB):                0.289
# Skew:                          -0.122   Prob(JB):                        0.865
# Kurtosis:                       2.244   Cond. No.                         29.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Administrator\anaconda3\envs\PythonForAnalysts\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   res = hypotest_fun_out(*samples, **kwds)
